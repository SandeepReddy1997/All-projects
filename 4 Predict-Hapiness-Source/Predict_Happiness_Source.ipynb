# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import string
import re
import textmining
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Load data

# %%
rawData = pd.read_csv('dataset/hm_train.csv')
rawData
# Out:
#         hmid reflection_period  \
# 0      27673               24h
# 1      27674               24h
# 2      27675               24h
# 3      27676               24h
# 4      27677               24h
# ...      ...               ...
# 60316  88299                3m
# 60317  88300                3m
# 60318  88301                3m
# 60319  88302                3m
# 60320  88303                3m
#
#                                               cleaned_hm  num_sentence  \
# 0      I went on a successful date with someone I fel...             1
# 1      I was happy when my son got 90% marks in his e...             1
# 2           I went to the gym this morning and did yoga.             1
# 3      We had a serious talk with some friends of our...             2
# 4      I went with grandchildren to butterfly display...             1
# ...                                                  ...           ...
# 60316  I got together with my best friend and baked c...             1
# 60317                I went to a restaurant with friends             1
# 60318  The other day on Mechanical Turk I made over f...             1
# 60319  Finished the semester today and aced majority ...             2
# 60320  An event that made me happy in the past 3 mont...             2
#
#       predicted_category
# 0              affection
# 1              affection
# 2               exercise
# 3                bonding
# 4              affection
# ...                  ...
# 60316            bonding
# 60317            bonding
# 60318        achievement
# 60319        achievement
# 60320          affection
#
# [60321 rows x 5 columns]

# %%
# For time being, Select first 1000 rows of text for fast processing
rawData = rawData.iloc[:1000, ]
rawData.shape
# Out:
# (1000, 5)

# %%
rawData['predicted_category'].value_counts()
# Out:
# affection           339
# achievement         323
# bonding             114
# enjoy_the_moment     99
# leisure              63
# nature               32
# exercise             30
# Name: predicted_category, dtype: int64

# %%
categories = sorted(rawData['predicted_category'].unique())
categories
# Out:
# ['achievement',
#  'affection',
#  'bonding',
#  'enjoy_the_moment',
#  'exercise',
#  'leisure',
#  'nature']

# %%
# Can be used for exploring
affection = rawData[rawData['predicted_category'] == 'affection']
exercise = rawData[rawData['predicted_category'] == 'exercise']
bonding = rawData[rawData['predicted_category'] == 'bonding']
leisure = rawData[rawData['predicted_category'] == 'leisure']
achievement = rawData[rawData['predicted_category'] == 'achievement']
enjoy_the_moment = rawData[rawData['predicted_category'] == 'enjoy_the_moment']
nature = rawData[rawData['predicted_category'] == 'nature']

# %%
# Download Repository
# nltk.download('popular')
# OR nltk.download()

# %%
# Extract stopwords
stops = set(stopwords.words('English'))
# stops_ = set(STOPWORDS)
# stops.update(stops_)


# Remove punctuation marks
exclude = set(string.punctuation)

# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# ### Removing stop words, punctuations, numbers, hypens, white spaces from text

# %%
# Text Pre-Processing

def clean(doc):
    doc_tokens = word_tokenize(doc.lower())
    stop_free = " ".join([i for i in doc_tokens if i not in stops])
    punc_free = "".join([i for i in stop_free if i not in exclude])
    num_free = "".join(i for i in punc_free if i is not i.isdigit())
    num_free_ = re.sub("\d+", "", num_free)
    hypen_free = "".join(num_free_).replace('-', ' ')
    result = num_free_.strip()
    result = re.sub(' +', ' ', result)
    return result

data_cleaned = [clean(rawData.iloc[i,2]) for i in range(0, rawData.shape[0])]
data_cleaned
# Out:
# ['went successful date someone felt sympathy connection',
#  'happy son got marks examination',
#  'went gym morning yoga',
#  'serious talk friends flaky lately understood good evening hanging',
#  'went grandchildren butterfly display crohn conservatory',
#  'meditated last night',
#  'made new recipe peasant bread came spectacular',
#  'got gift elder brother really surprising',
#  'yesterday moms birthday enjoyed',
#  'watching cupcake wars three teen children',
#  'came rd place call duty video game',
#  'completed miles run without break makes feel strong',
#  'went movies friends fun',
#  'shorting gold made trade',
#  'hearing songs nearly impossible go angry happy re looking thought eases angry feeling moves direction happiness may take long re headed positive direction youall world good',
#  'son performed well test preparation',
#  'helped neighbour fix car damages',
#  'managed get final trophy game playing',
#  'hot kiss girl friend last night made day',
#  'new bcaas came mail yay strawberry lemonade flavored aminos make heart happy',
#  'got class',
#  'sister called abroad morning long years happy occassion family members',
#  'cake made today came amazing tasted amazing well',
#  'two types people world choose happy choose unhappy contrary popular belief happiness nt come fame fortune people material possessions',
#  'grandmother start walk bed long time',
#  'able hit top spin serve tennis',
#  'napped husband bed afternoon sweet cuddle close',
#  'cowoker started playing carley rae jepsen song phone ringing customers',
#  'son woke fantastic breakfast eggs special hamburger patty pancakes',
#  'long time brother gave suprise visit house yesterday',
#  'went movies sister today first time since long time',
#  'consumed well garnished bowl ramen twice today delicious',
#  'picked daughter airport fun good conversation way home',
#  'daughter waved said mama first time came home morning',
#  'going mountains hiking trail top',
#  'competing another team online game playing friends childhood friends grew together went school since re kids ve playing game together almost years kinda formed team game game started smoothly everyone hyped fight slowly things started become interesting exciting know became close fight score point winner declared everyone looking since knew best within friends particular game started commanding expect enemies game team based game vs team starting fail demoralization ensues tried best knew maneuvered attack enemy skill luck dodged countered',
#  'went run neighborhood enjoyed perfect weather',
#  'hang fiancee dinner together',
#  'offsite colleagues great fun stimulating discussions',
#  'older daughter keeps patting younger daughter s head',
#  'feeling lonely long day s work called husband said way pick meeting surprised excited',
#  'received award work tough loan process helped develop',
#  'received flowers best friend',
#  'spouse gave kiss big hug morning go office',
#  'son gave big hug morning',
#  'cooked ate wonderful sausage cheese omelet',
#  'achieved daily income goal',
#  'met favorite superstar first time',
#  'remember yesterday totally different many mondays felt like spring finally sun bright temperatures warm',
#  'ate good dinner family',
#  'went shopping',
#  'phone ordered local online store delivered morning like phone much',
#  'today morning son s exam results came got distinction first grade subjects felt happy',
#  'bought new tv',
#  'national cricket team test match series morning win sealed position no test team world made happy today',
#  'made bunch extra sales side business last night',
#  'walked work back partner',
#  'got promotion today years service job',
#  'sister long chat happening lives right enjoyed reconnecting',
#  'woke early morning daily',
#  'partner buy big cake nice tasty i never expect cake partner really loves lot the cake delicious cold the taste different compared cake the day went interesting spent time partner we went movie fun i really miss partner day love spent',
#  'logged account mturk saw pending hits got approved still acceptance',
#  'slow cooked chuck roast stove came great',
#  'saw two close friends nt seen couple months',
#  'cooked girlfriend wonderful breakfast',
#  'today morning selected junior engineer leading familiar mobile sales company',
#  'smile son faces make happy everyday today also got',
#  'happy one day trade gave good profit today',
#  'took dog long walk beautiful day',
#  'running around kids husband grabbed told beautiful perfect smart special loved',
#  'yrs son felt bad kicking said mom m sorry kicking wont repeat i felt happy age realizes mistake',
#  'long ago men went sea women waited standing edge water scanning horizon tiny ship wait henry vanishes unwillingly without warning wait moment wait feels like year eternity husband comedy man moment happy moodmy baby born moment',
#  'lost kgs weight month long effort put achieve',
#  'finally learned cook chicken',
#  'girlfriend told loved hoped marry one day',
#  'tired work still managed go mile bicycle ride great since knee surgery months ago',
#  'took girlfriend nice birthday dinner got watch open presents really fun evening',
#  'going running exercising three days break',
#  'income taxes year nice refund coming',
#  'everyone works pace compare others think re better someone else gain unhealthy sense superiority think someone else better end feeling bad youall happier focus progress praise others',
#  'able pushups today highest ve done',
#  'mother gave surprise visit home',
#  'celebrated anniversary boyfriend',
#  'booked beach vacation may year',
#  'long time waiting finally got tickets favourite movie released yesterday first day first showit really awesome feeling still could feel wayi get goosebumps relive moment theatre',
#  'met city mayor given valuable advice development city',
#  'india series australia made feel happy',
#  'finished painting granddaughters bedroom',
#  'taking gym due illness able wake early complete normal squat workout weight done prior break',
#  'last night sister born baby got new relation uncle happiest moment',
#  'got new phone great never phone',
#  'son results today got good scored school happy see results',
#  'got travel visa tourist months australia',
#  'hi thing made happy finished tasks office got appreciation team leader work done yesterday moment made happy past hours yesterday performed well first time got team topper position moment made happy',
#  'could suryanamaskars mins would otherwise take mins',
#  'know sleep helps bodies recover day repair helps us focus productive turns itas also important happinessour commute office surprisingly powerful impact happiness',
#  'went sports club running exercise s feel fresh happy',
#  'got engaged parents support',
#  'found poet really love lot twitter',
#  'hardly traffic way work morning',
#  'got happy task mechanical turk got reward points made feel happy last hours',
#  'seeing friends able catch filled joy',
#  'came office right time',
#  'family went wildlife park beautiful',
#  'day got degree industrial engineering',
#  'frankly constipated past days able defecate today bowel got cleared moment really makes feel happy bowel feels well moment makes feel happy really',
#  'read great book motivation attitude',
#  'cricket match played really well',
#  'one happy moment happened past hours would went back work today first time years',
#  'woke early morning witnessed beautiful sunrise',
#  'taking nice warm shower really good relaxing',
#  'went vacation native placemy parents siblings thereit great feel familywe ate lot family fun',
#  'saw rainbow made feel happy since never seen rainbow reality',
#  'saw dad went office popular among staff many people know thing makes happy dad',
#  'yesterday night went movie familywe great fun spending time together',
#  'went office hour one professors realized caring professormentor ever',
#  'ladies member family went lunch seven star hotel n much fun ladies go together n gossip',
#  'made quite progress old rusty workbench restoring moment new paint looks like new',
#  'wife came home work shared steak dinner together bottle wine',
#  'julia good girl last night lunge trying hard asked without getting panicky throwing resulting wobbles',
#  'son went football match friends came home happy team matchseeing happy felt happy',
#  'morning years daughter apply ointment severe headache',
#  'getting errands done completed',
#  'gathering old friends school',
#  'today happier usual ate veggies put plate usually leave leaves plate today',
#  'able beat record bench press',
#  'summer holidays began kids happy',
#  'second essay twopart series journey visit taj mahal read first part whole story gra uttar pradesh india soon train agra leaves delhi find confused iam lying reserved upper berth though train car beds arenat used almost passengers sitting lower seats feel ridiculous like iam emperor train car overseeing rest passengers meanwhile men pass offering mysterious vegetarian curry industrialsized buckets motion one serve paper plate try pay food wonat accept money first time iave gotten anything free india conclude food going kill iam eating train makes stop passengers disembark conductor makes announcements canat see trainas tiny lower windows upper bunk idea ais agra ask man sitting ask nicely possible attempt avoid appearing selfrighteous train car emperor shouting questions serfs remember taj mahalbuilder mughal emperor shah jahan overthrown son soon taj mahalas completion man shakes head hindi think tells still long ride agra another man walks selling nonvegetarian food foil tins first shots intestinal war already fired result free bucket food decline train chugs toward agra stopping stations along way find continuously recruiting new serfs keep track time iam halfway journey eighteen year old kid two indian soldiers young woman none speak english trying assist itas easy accidentally aggregate helpers train mercifully indians tend especially protective clueless westerners trying make sense indian public transportation one point two indian soldiers demand teenager move feet resting berth young woman makes food recommendations buckets whisk theyare kind like four trainfairy godmothers soon fall asleep suddenly awake sound four indians chanting aagra agra unison abruptly end time train car emperor jump bed thank four catch taxi agra guesthouse leaves arrange taxi driver pick next morning take taj mahal morning tell driver take east gate taj mahal promptly takes roundabout near west gate instead though aeast gate announcement upon arrival quite convincing indiaas perpetually dishonest taxi drivers always ulterior sometimes mysterious motives case trying save gas taking gate closer hotel according lonely planet possibly collect kickback camel rickshaw drivers sitting near west gate waiting take tourists tajas ticket office donat bother argue since thereas much time sunrise walk quickly entrance standing line twenty mostly indian tourists iam surprised see lack westerners imagined every white person india would flocking taj mahal finally doors open catch first glimpse building considered beautiful world one whose creator boasted made athe sun moon shed tears eyesa see famous white marble dome peeking arch great gate tourists hold cameras high heads get first snapshot walk deliberately toward around taj soaking dawn slowly taking photos every possible angle handful photographers gather front adjacent taj mahal mosque capture sun rises behind everyone reverent taking care interfere othersa photographs offering help take posed pictures moment perfect photographer gaggle mist blankets yamuna river behind structure building looks like risen spontaneously clouded heaven concrete manifestation nirvana simple presence taj built symbol eternal love emperor jahan memory third wife died childbirth seems encourage even rabid photographers cooperate spend almost two hours touring photographing taj walking around walls admiring calligraphy entrance arch gazing minarets touching intricate lattice screens mausoleum interior iam finished taking final classic taj mahal reflection pool photographs outside beautiful young blond woman performing playful provocative poses friends camera catches eye soon string indian men indian families start interrupting ask pose souvenir photos athe indian tourists seem interested white skin blond hair white marble taj mahal say aiam pretty sure lot indian guys leaving pictures taja chuckles introduces sophie france quickly weare trading funny stories travels india like immediately find chatting front tajas reflection p ...
#  'father bought bicycle',
#  'cracked interview ibm made feel happy like never',
#  'flew one rc model planes around yard able maneuver around trees yard power lines side road sometimes minor crash s due confined space often able fly nice long flight without incidents one times super fun',
#  'went home given ice cream family pack family particularly hands son creates joyful moment',
#  'son came home said study words wanted bond working together',
#  'went grocery store buy cooked whole chicken deli found halfprice day',
#  'went movie friends popcorn cokewas fun',
#  'neice nephew gave hug kiss today morning',
#  'laughed english class silliness last period',
#  'today got driving license wheeler wheeler since last week waiting driving license',
#  'completed flashcards upcoming test',
#  'little things went gym today squats leg lifts powercage open afternoon',
#  'daughter good big test school',
#  'able sleep longer usual',
#  'yesterday solved big issue related family',
#  'past hours talked friend nt call often',
#  'long talk son lives far away fro always good conversations',
#  'finally mastered make crispy tofu',
#  'long weeks deep snow covered ground finally enough warm days northeast snow melt able start day fantastic hike appalachian trail runs nearby home felt though entire life suddenly came back balance held back weeks due enormous amount snowfall',
#  'working principal applied post ceo today morning received confirmed notification mail happy whatever expected gave everything post thanks remembering incident',
#  'got bonus work creative idea came enhance safetyi buy something nice',
#  'husband says love u woke morning',
#  'run run run run finally catch bus disappearing form eyes make feel nice',
#  'left key motor cycle searched half hour neighbor house uncle came gave key happy',
#  'able get xbox game',
#  'saw girl loved much mui ne bay face loved missed much',
#  'riding home sunny cool afternoon along riverside path',
#  'got promoted senior manager yesterday happy',
#  'met college friends today good time together enough time chatting went favourite destination cream centre explored delicious taste ice creams',
#  'took time played pet rabbit',
#  'husband told loves morning',
#  'oldest dog suffers congestive heart failure seemed feeling much better today felt quite relieved',
#  'super good mail day yesterday received lots items ordered amazon',
#  'family went watch film',
#  'ate peanut butter ms watching john oliver delicious hilarious',
#  'day morning trained neighbor child run cycle enjoyed lot',
#  'went dinner friends enjoyed lot',
#  'able play video game enjoy quite bit made relaxed happy',
#  'run miles feeling great',
#  'got pet gift parents',
#  'intimate relations wonderful person love',
#  'sore throat cleared',
#  'got see girlfriend help celebrate birthday',
#  'brought new mobile day morning',
#  'enjoyed play soccer brother',
#  'went power walking local mall many walkers smiled waved',
#  'happy moment granddaughter gave big hug kind girl gives hugs lot got hug wonderful',
#  'past hours made happy mother s day card year old son written kindest sweetest note surrounded beautiful drawing',
#  'went long run trail near house',
#  'came home work dog wagging tail previously convinced hurt yesterday nt wagging',
#  'got engaged lover yesterday',
#  'able full hour research topic nagging',
#  'playing rock band family',
#  'wife celebrating ten year anniversary today',
#  'happy daughter called across country',
#  'daughter came first sports race feeling proud',
#  'well yesterday started early waking mturk task woke find got unexpected bonus someone hardly scraping disability checks small side jobs dont pay enough cover bills even cent bonus help honestly nice see work helping',
#  'month bought new tcl inch led tv looks cool really loved',
#  'solving engineering mechanics problem made happy',
#  'went lunch girlfriend family',
#  'took dog walk around local park almost degrees beautiful day',
#  'woke took care daughter smiley first thing morning amazing seeing smiles',
#  'happy realized biggest concern sang drinking',
#  'got train station pulled able get seat',
#  'wife told despite lost overtime hours happy around',
#  'went support cousin product launch last night happy proud watch shine',
#  'went park son work yesterday',
#  'turbo kick class full last night',
#  'able successfully assist friend job search setting interview',
#  'cooked new recipe dinner turned great',
#  'spending time daughter good friends inservice last night',
#  'met buddies drinks dinner last night great able hang watch hockey',
#  'played new game fun got enjoy mechanics',
#  'happy family brings beautiful gift',
#  'husband passed dot physical nt worry anymore',
#  'weather warm gorgeous first time long time m loving',
#  'great lunch daughter grandchildren enjoyed time together',
#  'met old time friends',
#  'weighed morning found weight thought',
#  'met childhood friend years',
#  'go hotel party moms birthday',
#  'children kissing goodnight',
#  'girlfriend surprised favorite dinner tacos',
#  'get come home earlier boss vacation',
#  'went restaurant family members',
#  'playing kittens',
#  'great way sum feeling happiness itas everything feels like itas clicking itas sync part equation breaks start lose handle happy feelings thatas itas important always speak true feelings act according way re feeling inside',
#  'able resist drink last night',
#  'cooked food motherinlaw liked',
#  'dinner family dad getting sick',
#  'hot chat dating partner makes feel sexy',
#  'finally tricked dog letting give bath sweet smelling puppy best',
#  'talked old friend',
#  'seen parents filled tears receiving phone call huge amount happiness words explain',
#  'nt deal annoying customers work morning happens blue moon',
#  'mucha salade perigourdine full goodies glass nice red wine personal ai assistant writing better emails happiest moment last hours reunited best mate luke took',
#  'finally completed project enthusiastically',
#  'got job interview dream job',
#  'motherinlaw offered money could buy yogurt ca nt afford buy',
#  'friend came visited work talked minutes',
#  'mobile home park manager called said coming morning fix leaky swamp cooler finally',
#  'finally decorated son s room birthday',
#  'cooked entire breakfast family',
#  'went local gym lift weight cardio shower afterwards refreshing',
#  'rain stopped beautiful sunlight appeared went walk took photographs',
#  'application adopt cat came',
#  'taking dog walk conversation stranger',
#  'traveled family went beautiful beach enjoyed attraction area s entertainers everywhere lot people gathering music bands partying pleasant experience hope return anytime soon',
#  'son gave big hug morning woke',
#  'brother got interview job applied s likely ll get hired',
#  'offsite colleagues great fun stimulating discussions',
#  'older daughter keeps telling wants go bathroom',
#  'weather sultry place ac unit damaged rodents electrician came earlier today repaired thank god need sweat today',
#  'celebrated th wedding anniversary wife',
#  'met weight loss goal bet nt easy',
#  'went walking morning',
#  'wife wear favorite saree office meeting',
#  'spoke exwife phone made plans see son thursday',
#  'purchased product wanted fifty percent retail price',
#  'got promotion',
#  'anything else daughter s birthday turned special day made day special',
#  'played tennis friends',
#  'daughter visited evening',
#  'wife told passed qualifying exam job promotion',
#  'garden planted rose plant last monthyesterday morning beautiful colorful rose flourishedit made happy',
#  'delicious lunch',
#  'two wheeler running found issue front tyre managed made happy',
#  'really good carbonara chicken dinner',
#  'cleaned bathroom tiles looks nice shiny',
#  'brought new game system today',
#  'made dinner boyfriend complimented felt happy compliment able make happy',
#  'measured weight found pound lesser earlier day',
#  'today morning went shopping time seen one accident unforgettable a small boy crossing road time one man ride cycle fast kick boy cycle unfortunately boy fell get wounds leg hand he shouted lot cry then went closer boy took hospital return safe home',
#  'received call new client ready pay usual simple design',
#  'doubled daily goal mturk rewards short amount time',
#  'smoked bowl marijuana',
#  'able eat dinner one best friends',
#  'appointment order given surprised salary doubled getting',
#  'yesterday son want ride bike move got happy me',
#  'buying medicine regular pharmacy store came know unused points old purchases pay anything medicine bought',
#  'found tool looking long time',
#  'daughter said donald duck first time said daisy',
#  'happy yummy mango year today',
#  'always think night song moment songto feel much know eyes eagle slope mountain wave understanding influence moon tree read memory leaves insignificant pedestrian streets crazy cities watching watching watching',
#  'kid got promoted next class',
#  'completed long time pending project',
#  'received enough funding start research project abroad summer',
#  'play competitive game online able get top score among friends also play usually get somewhere top scores',
#  'finally went run worked felt great taking care body',
#  'nice conversation wife neighbour rarely speaks seems nice',
#  'spoke college friend angie minutes first time since last summer',
#  'homes extension within walls abodes shapes mood affects productivity influences outlook life scientific studies shown impact happiness adjusting tiny little habits routines constitute daily lives fact control outlook life',
#  'lot favorite shows updated recently able watch today',
#  'able leave early office amazing evening mother wife',
#  'ate really good chinese food',
#  'paid bills money usual left transfer savings',
#  'long debate finally convinced parents buy new laptop todayas promised also bought new one happy satisfied',
#  'get back home wife make good food like',
#  'friend gifted ring paper selected national conference',
#  'took shower wife',
#  'able go grocery store saved money buying impulse items alcohol trying stay away',
#  'today early morning boss call surprised boss say got promotion salary increased',
#  'took walk girlfriend night',
#  'went movie telugu movie favourite hero new movie released awesome movie',
#  'daughter got rewarded best english speech class',
#  'next thing made happy got one special offer telecom service reduced package plan moment made happy',
#  'could finally eat favourite restaurant long time',
#  'recently became friends really great group people yesterday ordered pizza chinese taco bell sat around talking eating good timestalking sister law eating chocolate custard spending time youngest child',
#  'yesterday evening friend played badminton enjoyed',
#  'got surprise gift parents',
#  'husband purchased things like market',
#  'got home work girlfriend greeted hug dinner already prepared setup table',
#  'met childhood friend long time got hug moment wonderful',
#  'able celebrate fathers birthday treating dinner able see happy truly made happy',
#  'ride bike speed km per hour',
#  'cleaned kitchen feels great',
#  'find new job',
#  'ordered product amazonin got delivered today moment makes feel happy',
#  'story advices got reading',
#  'puzzle game website requires fast reflexes',
#  'another happy moment happened past hours one year old daughter took steps morning',
#  'woke young daughter morning school insisted would make breakfast consisted coffee toast',
#  'reading comics books whilst drinking cocoa drink',
#  'offsite colleagues great fun enjoyed perfect weather enjoyed watching sunset porch',
#  'completed work target boss appreciated good work moment felt happiness',
#  'eat sugar candy party long reminds childhood',
#  'today got bonus amount dollars requester mturk',
#  'went get sushi highschool friends like small reunion',
#  'early morning got many messages n wishes friends n family members s new year today i felt loved everyone',
#  'joked around mum got home work made happy turn made happy well',
#  'wife shared pleasures us happy',
#  'watching field full horses work mad happy hon getting stunning recalls little dogleg',
#  'returning home worki helped old couple reach destinationthey blessed us made happy',
#  'received call letter university job',
#  'spending time parents',
#  'online game get new event give many diamond',
#  'worked back biceps',
#  'got finish tv series watching mom',
#  'got offer pizza nearby hotel happy',
#  'sunset time sun goes night begins sunset nature assumes fresh bright charming sun seems disc gold time sunset one enjoy serenity sunset nature seems hurry people finish work return home birds return nests cowboys become busy returning home cattle sun sets nature looks beautiful nature starts getting dark slight darkness sunset creates feeling joy tranquility us beauty sunset helps poet generate ideas compose poems',
#  'celebrated birthday friends',
#  'got respect friends social welfare thing',
#  'got early daylight went outside fly one rc quadcopters equipped led lights lights make easy see orient quadcopter still somewhat difficult see trees obstructions yard able fly minutes around yard home neighbor s yard permission flying total darkness challenging super fun',
#  'given aadhar card update poor man minimum cost moment felt happy',
#  'found new community moving pond kayak launch',
#  'extra memory purchased computer arrived today easy install',
#  'husband bought favourite sweet really made happy',
#  'finally got drivers license',
#  'really good rehearsal friday night s play',
#  'today afternoon pm husband suddenly planned vacation tour booked ticket whole trip nt expect husband',
#  'made tasty chocolate pudding every one enjoyed',
#  'payday everyday payday happy day able finally pay last remaining balance birth twins',
#  'husband made favorite food dinner',
#  'level games',
#  'happy solving major issue',
#  'watched series movies',
#  'one last azalea bloom came today happy see flowers killed late frost weeks back',
#  'got offer help photographer friend shoot cubs season opener game',
#  'able find time go hair cut something putting month looks great',
#  'met old friend studying years back link unexpectedly met airport surprise later remembered childhood days present life',
#  'got computer fixed finallynow get back things need get done',
#  'participated ugadi food festival office',
#  'done job planned pleased',
#  'wrote mba assignments sent study center courier saw papers inserted phoned courier office told send cover went kept papers time really happy',
#  'got new iphone plus product red',
#  'basketball medal team leader mvp match',
#  'triathlon gear d waiting arrived last pleasing positive resolution seller pleased purchase fits performs really well',
#  'friends thrown surprise party promotion yesterday happy',
#  'friends went favourite amusement park end street great time went amazing rides elated ecstasy',
#  'finally finished new york times crossword working',
#  'friend called tell possible job opening field',
#  'mechanic contacted repairs truck much less expensive anticipated',
#  'able stay calories yesterday continue fast eat friends weekend',
#  'hole family dinner',
#  'played dog outside sunny fun',
#  'last night went hotel dinner girl friend',
#  'got gift brother without reason',
#  'able go workout coworker mine prepped day made happy',
#  'managed earn dollars one hour work',
#  'day make breakfast parents',
#  'felt baby move belly first time',
#  'got positive comment work',
#  'able run outside complete k new record time nice weather feels like spring',
#  'yesterday received message got promoted manager company',
#  'love watching sunset beach',
#  'went costco daughter buy anything',
#  'driving home house saw beautiful sunset',
#  'sitting outside drinking cup tea sunshine surrounded recently bloomed tulips',
#  'eating lunch mom dad',
#  'someone needs retire work breathing heavily like lungs going quit lazy worker want leave',
#  'brought dresses parents day',
#  'able hit earnings goal day thought originally high',
#  'got extra sleep last night',
#  'mother called blue tell proud',
#  'happy lunch husband',
#  'maid cooked delicious meal today family',
#  'like said wake early get started mturk yesterday morning daughter stoped got coffee morning nice much needed',
#  'month bought new tcl inch led tv looks cool really loved',
#  'playing cricket friends',
#  'found bag thought lost',
#  'watched kids playing together fighting',
#  'made delicious homemade pad thai husband happy eat give many compliments',
#  'bet morning',
#  'job provided lunch really good',
#  'ran longest duration far',
#  'made chappati first time turned amazing',
#  'cooked dinner son made meatballs',
#  'year old came sat lap watched tv',
#  'made delicious meal using fresh ingredients without go grocery store',
#  'passed evaluation work flying colors',
#  'inservice looking forward attending ended great time friends daughter',
#  'really happy find friend mine getting married even asked wedding',
#  'listened music heard entire album nt heard',
#  'happy got new incentives hardworking work',
#  'went bible study tonight special needs friends',
#  'fiance found old magic gathering cards brother going throw brought home',
#  'made vacation plans daughter today florida july',
#  'ate favorite dinner',
#  'difficult dog hardly ever listens finally decided come today called',
#  'mother prepared special biriyani friend',
#  'go theatre make happy family',
#  'husband kissing hello',
#  'played tugofwar new dog leo',
#  'shared big breakfast boyfriend',
#  'got bonuses work m getting regularly',
#  'got email old friend',
#  'may take long youare headed positive direction ll world good going internal system guidance sure way feel less perfectly happy always strive lining three aspects happy life',
#  'mother recovering weakness chemotherapy cycle',
#  'brought gifts siblings',
#  'watched new episode show like',
#  'good win sports team',
#  'managed get eight minute mile pace m kind awesome',
#  'bought new wallet looking',
#  'car loan cleared yesterday happy',
#  'got test barely studied',
#  'might think would money power fame well think positive psychology guru martin seligman studied happiness found characteristics happy people rate comes feeling happy',
#  'become leader great squad achieved highest rank',
#  'gt exam',
#  've thinking dreams life death reflection ve made feel complete peace',
#  'got new underwear mail purchased online',
#  'pen pal vermont called unexpectedly ve friends years hope meet person day',
#  'enjoyed dinner brother family garden restaurant yesterday',
#  'beat final boss dark souls',
#  'drove around town run errands much traffic spring break',
#  'cat sick yesterday ate food scampered around apartment',
#  'husband got promoted job making money',
#  'meeting girlfriend park talking',
#  'family went travel nearby beach saw beautiful performance pyro dancers first time encountered talent really impressive say anything performance petrified awe saw could move scenario even performance ended could help think thought time would see performance visit place hopefully come across specific performers',
#  'offsite colleagues great fun stimulating discussions',
#  'computer hard drive failure got finally repaired',
#  'son gave big hug morning woke',
#  'younger daughter lift head',
#  'struggling relocate wardrobe near windows husband without knowledge back dropping kids school',
#  'worked able keep entire tape',
#  'completed office work went nice brunch parter',
#  'enjoyed watch soccer',
#  'offsite colleagues great fun stimulating discussions',
#  'received message seemingly charming lady plenty fish dating app',
#  'found something lost weeks',
#  'bought new phone',
#  'got see good old friend came daughter s birthday',
#  'finished work earlier usually',
#  'went park',
#  'able reach target weight today kg need lose still happy',
#  'last evening office got gift containing tour package including family success project felt surprise happy',
#  'went gym',
#  'made tea morning ginger wife liked much made happy',
#  'found great deal samsonite backpack',
#  'talked mother phone half hour',
#  'went co workers celebrate promotions',
#  'picked cat turned arms seemed hug back purring happy happy',
#  'bought new tshirt',
#  'eagerly waiting see friend engagement function she really cute beautiful she happy engagement loved one my friend character really good adjustable partner also kind humble they made they loved long years living together relationship understand well get soon get married',
#  'went movie without much expectations turned one best movie seen',
#  'rain stopped able take long walk dog daybreak',
#  'met group people nt seen almost half year',
#  'able play favorite game hours',
#  'lunch time lovely wife gave special hug sweet kiss',
#  'went sons school open house yesterday teacher told positively made happy',
#  'india cricket test match australia today',
#  'great dinner baked chicken hominy bread salad',
#  'mom took us dinner ate shrimp chimichanga',
#  'went ride enfield bullet morning weather husbandits awesome',
#  'formative years company employed foreign experts improve production management foresight establish r department even though product range small',
#  'long time best friend came visit family many years',
#  'replaced television home',
#  'found going start new highly potent new medication ibs believe could finally provide relief',
#  'former manager extended sick leave due injury came back work yesterday first manager got current job mentored',
#  'played guitar first time really satisfying make music',
#  'good dinner nice restaurant coworkers',
#  'nt take kids school today s first day spring break',
#  'one reason experiences memories experiences make us happier material things due entire cycle enjoyment experiences provide planning experience looking forward experience enjoying experience remembering experience make home gallery positive memories',
#  'lunch friend nt seen awhile',
#  'watched favorite movie wife late night',
#  'finally got job interview',
#  'spent time relaxing husband watching television',
#  'today travelling bus met stranger long talkthe man met equal bookshe amazed many facts experiences lifehe also gave many life hacks deal many day day problemsi glad new friend today',
#  'claim back insurance money insurance company',
#  'got appreciation academic performance head mechanical department',
#  'made love wife',
#  'finally able complete several small tasks work todo list awhile always superseded tasks',
#  'last night father gives gift bike special also happiest moment',
#  'saw dig work',
#  'cousin came native see son staying london today came home happy see house',
#  'cousin brother got engaged love years',
#  'third thing made happy got one credit card offer increased reward points purchase also offered free movie tickets exclusively credit card makes happy',
#  'could help rescue one puppy suffering street seeing since one month gave inner peace happiness',
#  'failed programming class last hours started completed basic python big achievement mei really happy momentwent get bed noticed daughter tucked picture drew saying bedtime surprise super sweet made day',
#  'got challenging work boss',
#  'got huge amount gift friends engagement gift',
#  'son sang song',
#  'brother called night check',
#  'got offer avail loan bank low interest rate made happy',
#  'completed goal bicep curls gym working couple weeks able accomplish easily today',
#  'ate favourite food item lunch',
#  'husband made delicious breakfast',
#  'best friend birthday',
#  'running business got order normal moment makes feel happy',
#  'feeling motivation moving right direction know',
#  'dinner family went new restaurant nearby',
#  'one thing made happy past hours would almost three year old son gave kiss cheek told loves',
#  'due cooler weather afternoon finally managed prune trees garden',
#  'got wanted seats cinema made watching movie experience whole lot better',
#  'met old friends yearswe talk half daywe played football like old days',
#  'usually play game got struck level yesterday completed level made happy',
#  'today make eye contact crush also look eyes seconds two still memorize beautiful eyes',
#  'drizzling morning went walk love weather',
#  'took mom small hill lake elsinore filled lot flowers',
#  'last night sister got new car went drive new car',
#  'managed one legged squats right leg weaker left process leveling happy progress',
#  'finally got taxes completed feel happiness relief s done',
#  'lol vix made giggle mine horse ultra soppy today grooming brushed good boy one buck today yesterday riding',
#  'little one months old waiting first stepshe took first step yesterdayseeing felt happy',
#  'play along daughter friends',
#  'good nap',
#  'holiday sunday im happy',
#  'drank ounces glasses water',
#  'finished paper college class',
#  'made cake tasty everyone home enjoyed',
#  'morning walk good exercise earlyriser regular morning walker benefits morning walk manifold early morning everything looks fresh fair atmosphere remains pleasant calm morning walker breathes pollutionfree air enjoys lovely sights sounds nature soothes soul regular morning walk keeps one fit helps form sound health science says morning walk controls blood pressure lessens stress strain energizes one work zealously nowadays live fast life work round clock hardly time care health habit morning walk formed right early days sure sound body sound mind besides health benefits extremely delightful experience take walk early morning',
#  'went temple parents',
#  'finally succeed making tomato soup',
#  'took small refractor telescope yard look stars planets able view jupiter moons surrounding planet though would love much larger telescope one performs well short focal length eyepiece view jupiter nice indeed',
#  'given rs donation expenses temple fund happy',
#  'daughter told best cook',
#  'dinner able enjoy quiet moment porch coffee cigar',
#  'long time today cousin came home surprisingly made day',
#  'enjoyed meditation shaolin temple nearby',
#  'nice conversation good friend work',
#  'went birthday party son s friend today talked friend s mother openly chatted happily nice lunch party got new friends son enjoyed lot',
#  'managed throw items cluttering room enjoyed space',
#  'son great soccer practice really coming along learning new skills well really learning control body',
#  'bought brand new dress looks beautiful',
#  'got book movie ticket',
#  'elders blessed daring powerful guts',
#  'live tweeted group fans',
#  'able fit back pair jeans able wear year',
#  'warm enough drive car windows open',
#  'good friend informed dave chappelle stand comedy acts released netflix ended evening yesterday huge grin face',
#  'spouse underwent cancer medical treatment major scanning doctors said nothing worry perfectly good take home happy',
#  'got get together people church help retirement homeit always good feeling help people',
#  'log walk friends heavy lunch',
#  'came home years son hug waiting',
#  'got rs cash gift quiz participated three months useful correct time felt happy',
#  'seeing friend nt seen long time',
#  'day saw working coffe house beautiful',
#  'finished reading crime novel john harvey nt think would read rest last night got hooked towards end',
#  'finally purchased dream house yesterday feeling happy',
#  'friends went favourite restaurant ate special dishes went astonished taste delicacy',
#  'spent time kitchen making chicken soup',
#  'cooked tasty dinner leftovers',
#  'called sister wish happy birthday nice telephone chat',
#  'weather starting warm m super happy',
#  'enjoyed week end family',
#  'colored adult coloring book watching netflix relaxing enjoyable',
#  'day morning joined gim',
#  'met school friends enjoyed lot',
#  'able play outside child weather nice made happy',
#  'got wet spring rain',
#  'day went cinema girlfriend',
#  'satisfied many food cravings dinner',
#  'meeting older friends nt seen',
#  'got tickets see favorite movie playing right even though sold currently',
#  'went temple parents',
#  'went run neighborhood enjoyed perfect weather',
#  'watched bates motel favorite television show',
#  'son took eat nice restaurant',
#  'walking first morning light dog sun creeping behind rushes birds full song',
#  'watching new episode favorite television show',
#  'made delicious meal',
#  'received lottery amount today',
#  'talked mom phone amazing call',
#  'cat snuggled leg sleeping',
#  'today took day part time job go brunch date wonderful wife',
#  'happy made sale business',
#  'rained today made surroundings beautiful',
#  'finished mturk work bit early since weather nice went worked pile firewood yard smaller pieces good stacking tossed grill fired right smoked chicken turned amazing',
#  'month bought new tcl inch led tv looks cool really loved',
#  'getting approval coffee girl crush',
#  'bakery gave extra pastries end day',
#  'went shopping local thrift store found great deal two chairs',
#  'watched always sunny philadelphia show always makes laugh happy',
#  'accomplished errands day spare time relax',
#  'started new project work something really interesting seems like fun work',
#  'spent time friends creative endeavor',
#  'husband cuddled watched movie together',
#  'got talk mother phone last night nt spoke needed',
#  'pork cooked dinner last night turned well worried would nt',
#  'able go bed early accomplishing chores earlier anticipated',
#  'got unexpected call daughter nyc',
#  'four daycare kids give hug goodnight laid nap',
#  'happy come work find huge project canceled big relief',
#  'hanging friends',
#  'able walk dog around neighborhood fun see flowers people planting',
#  'wonderful meal girl',
#  'enjoying key lime yogurt morning breakfast',
#  'completed fitness goal morning set ago run full mile going work',
#  'walking home work saw family park walked past joined',
#  'happy return home russia morning',
#  'mowed lawn yesterday makes happy outside working',
#  'old friend renee invited dinner',
#  'sitting porch rocking chair holding little girl son came spontaneously hugged us',
#  'got accepted college applied',
#  'getting work particularly busy night made happy',
#  'happy wife s work friends came visit',
#  'one thing made happy past hours spending quality time girlfriend',
#  'shopping made happy',
#  'went meeting peruvian dances friends',
#  'snuggling dog give stinky breath kisses',
#  'found ordered book online like lot',
#  'went walk great talk random stranger morning',
#  'one students told pretty',
#  'received birthday gift mail good friend mine',
#  'suffering fairly severe constipation last week experienced relief morning',
#  'talked girlfriend recently told loved',
#  'finally chance talk things really bothering good friend',
#  'made happy getting lunch felt fulfilling even burger fries',
#  'enough time make doro wat chicken store berbere sauce great',
#  'neighbor came see completion project gave many positive compliments made happy',
#  'finally able order things saving past months',
#  'able make older women s day grocery store',
#  'able find good batch mechanical turk hits',
#  'able go restaurant like',
#  'started watching black mirror good',
#  'shoveling neighbor s driveway couple weeks back surprised ordering pizza dinner',
#  'got take patient floor hospital never',
#  'daughter helped clean kitchen without asked',
#  'watched hour training dvd zbrush',
#  'really tough workout morning managed complete running incredibly quickly',
#  'great cup coffee woke',
#  'daughter smiling first woke saw face',
#  'looked time realized half hour got work',
#  'finally enough money amazon payments account buy vertical smoker wanting',
#  'went grocery shopping purchase food cook wife',
#  'went see get wife',
#  'played cat licked face hour',
#  'woke wife giving huge hug smile',
#  'got really excited periodically thinking upcoming weekend plans husband going go weekend trip filled new foods shopping watching new movie coming ghost shell',
#  'past hours family saying trust responsible thing made happy',
#  'went walk early morning air clear crisp',
#  'wife came home work day',
#  'talked preacher church fiance wanting get married',
#  'finished project working hard work',
#  'cat sat lap purred read book',
#  'made pizza home wife delicious',
#  'partner woke give kiss left work',
#  'diet seems working clothes fit bit looser',
#  'year old son excellent job completing science project',
#  'got home grocery store husband vacuumed floor taken trash without asking',
#  'enjoyed swimming beach near chennai',
#  'getting call client confirming purchase order',
#  'happy run dungeons dragons campaigns friends',
#  'piece richest moist chocolate cake ve ever',
#  'went last night friend made awesome drink chocolate syrup bailey s irish cream',
#  'finished caloric logging day calorie counting app provided feedback stating would weigh lbs less next week',
#  'finally able take necessary steps start learning japanese finally read first sentence felt really great inside',
#  'ran two miles fast pace never achieved',
#  'played grandchildren local park happy',
#  'giant chocolate cup cake',
#  'happiest last evening painting garden',
#  'got raise work went evaluation yesterday morning heard back hours ago',
#  'morning nephew sister law came visit along mother law',
#  'conversation girl met online today',
#  'sold motorcycle got thousand dollars lot',
#  'hung close friend last night dinner drinks',
#  'went hour run made feel great feel getting better shape makes feel good',
#  'checked weight lost pounds since started dieting months ago',
#  'sat outside backyard enjoyed greenery sun shone face',
#  'went gym today run minutes straight',
#  'wife made chicken soup',
#  'going gym lunch break made happy',
#  'beautiful weather outside makes happy',
#  'package arrive door',
#  'received bonus work',
#  'ordered dress fitted nicely',
#  'day work able binge watch tv show interruptions',
#  'saw baby ultrasound monitor',
#  'last night favorite hockey team played really well playing bad game night',
#  'visited new park area enjoyed nice walk',
#  'hit work goal earlier expected could actually quit wanted like hits',
#  'getting see relative lives another state',
#  'went eat favorite burger joint burgers delicious complete bliss',
#  'able run miles ever done',
#  'happy went dinner last night friends nt seen months',
#  'coffee made incredibly happy',
#  'son good took play mall even though children nt',
#  'best day turk ever yesterday working hard help supplement income start working towards full garden hen house',
#  'able cell phone service plan significantly reduced caused great deal happiness yesterday',
#  'art contest today first prize free dvd',
#  'got go yoga relax hour',
#  'lottery scratch never win things time',
#  'finally cleaned basement',
#  'got spend time playing board games online girlfriend currently miles away time spend together treasured valuable',
#  'woke good nights sleep sense satisfaction hit',
#  'got new laptop awesome',
#  'reminded love eli manning much s honestly talented quarterback forgotten long saw funny gif brought back many happy memories',
#  'past hrs happy amazed boss told entitled bonus relation new project made perfectly big help wife s happy felt fortunate happy life nt received amount money company first time',
#  'pleasant conversation girl like',
#  'strength training minutes',
#  'djed online',
#  'new boss appreciated work put',
#  'mowing raking maintaining lawn two oldest children happily helping entire time',
#  'basketball team game last seconds',
#  'happy got home work ate piece tiramisu wife made',
#  'friend sent funny picture',
#  'felt really happy work yesterday s relaxed worth place lunch break went outside sat padio cold beer vape pen watched youtube phone basking sun minutes great felt rejuvenated good mood felt happy',
#  'bought new pistol took range able shoot good',
#  'finally received pep boys rebate form prepaid visa card mail promptly used purchase item wanting amazon',
#  'lunch took long walk around block near office lots sun many cars passing',
#  'went jog',
#  'went gym able bench press lbs',
# ...
#  'met friend lunch nice time socializing',
#  'pet cats curled napping made happy close',
#  'woke exercised half hour happy starting hurt less made brighter beginning day',
#  'happy going physical therapy morning made feel better later day',
#  'saw friends seen good reconnect',
#  'cat snuggled slept',
#  'begun looking home buy feel hope future',
#  'within past hours made happy taking long nap stressful day studying',
#  'ran morning miles usually go miles pushed today see far could go',
#  'got spend evening husband enjoying s company',
#  'hit goal walking miles day',
#  'working problem morning found solution problem happy words describe feelings',
#  'son got cold drink kissed forehead nt feeling well',
#  'made goal losing pounds',
#  'went walk around block',
#  'roommate made breakfast morning',
#  'wife came home early work got spend extra time together',
#  'husband kind sweet morning sat talked ate breakfast waited see',
#  'teen daughter made cup tea last night set next bed',
#  'went gym really enjoyed awesome workout afterwards',
#  'boyfriend gone spring break visiting family got back yesterday nice wake next cuddle apart',
#  'carnival corp reported beat estimates stock going way right bunch invested',
#  'got eat really delicious noodles mom made',
#  'bought new laptop',
#  'friend mine verge crying threw clutched clothes sighed relief held tightly overwhelmed found comfort embrace',
#  'tried book doctor s appointment opening next day',
#  'talking phone mom morning',
#  'monday work inservice day',
#  'bought new pair headphones',
#  'adapted stage musical filmtheater actor oh manseok debuting director oh also lyricist polished script story centers around two guys crazy music one high school music teacher beomjin broken girlfriend eats sadly alone front mirror habit another younger saeki whose mother left whose father died sudden accident leaving orphan rather dull world thing makes two feel alive music offering happy life yoo junsang im choongil alternated beomjin kim muyeol ryan alternated saeki',
#  'dinner parents',
#  'bought jacket admired got great deal',
#  'girlfriend came cuddled fell asleep',
#  'found good amount things watch twitch enjoyed quite lot',
#  'able make time playing video game nt gotten around',
#  'received free sushi coworker',
#  'last hours husband decided going renew vowels made excited know still love years marriage',
#  'went watch soccer match stadium fun cheering team',
#  'watched tv show stepdaughter',
#  'friend treated nice lunch seafood delicious nt pay anything',
#  'woke morning back pain gone away completely',
#  'happy picked month old daughter first day day care yesterday saw bright beaming smile',
#  'managed eat calorie goal day felt accomplished',
#  'got paid monday immediately used money pay long time credit card debt dentist finally free',
#  'favorite hockey team winning yesterday',
#  'got finally help mom get new doctor make appointment asking help months nt know use internet search new doctor kp website',
#  'receiving high score hard college exam paper',
#  'received praise boss project completed',
#  'spouse gave big hug morning',
#  'watched movie spouse rubbed sore feet',
#  'enjoyed cup coffee morning',
#  'watching bob s burgers streaming fox',
#  'got ten dollar bonus requester mechanical turk nt even remember hit',
#  'got new role project manager team m working sidejob',
#  'deciding skip gym night spend couple extra hours together girlfriend',
#  'wildlife center volunteer injured beaver made full recovery able bring back home',
#  'talked phone girlfriend ve sick',
#  'year old son trying impress mother yesterday dinner asked piece chocolate mini hershey bars put one counter son pointed chocolate bar finger moving across letters said mom says turkeys made laugh',
#  'daughter climbed bed snuggled pretending kitten',
#  'got relax spend time girlfriend worry anything else',
#  'went nice evening walk around neighborhood wife',
#  'got complimented looking buff',
#  'children got morning received big hugs kisses',
#  'able take minutes relax prior starting work made happy focused',
#  'picked new bedspread bed bedspread holes needed replaced husband happy length width spread',
#  'talking sisterinlaw phone yesterday evening since last time talked really enjoyed reconnecting',
#  'made money expected mturk',
#  'managed make next prize level hearthstone s tournament mode previous high',
#  'well videogame playing',
#  's son s eighth birthday four days fun going baby pictures old birthday photos',
#  'poker local bar bought round drinks everyone cause felt good still happy event even morning',
#  'ate nice dinner delicious steak',
#  'got home work dog greeted kisses wanting pets made happy greeted see happy',
#  'got done test nervous taking think pretty good',
#  'lunch mom one favorite spots',
#  'last night watching movies three friends home place amazing day tired wanted spend time couple hours great divine feeling working hard loved ones enjoying moment hours',
#  'received award excellence teaching university wonderful honor beautiful reception part',
#  'found wrong internet modem able fix',
#  'able see doctor receive medicine horrible cold',
#  'son told loved beautiful face',
#  'finally repaired problem car needed help managed mostly',
#  'beautiful garden',
#  'got puppy saturday makes happy cuddles',
#  'relaxed played mass effect computer',
#  'fall love girl iall never know sat across starbucks unknowingly stealing breath away yes iall never see hour love',
#  'helped client learn stretch less pain',
#  'met year old aunt lunch caught family news',
#  'employer offered switch part time full time work',
#  'favorite tv show new episode watched',
#  'eating sriracha sour cream mashed potatoes turned exceptionally well',
#  'went shoot pool friends game',
#  'got bonus mturk task',
#  'able master song practiced instruments',
#  'went bouldering gym good friend',
#  'managed pushups finally',
#  'morning wife gave hug told important person world',
#  'managed vape good portion day yesterday m trying quit smoking every time make healthier choice s job well done',
#  'saw man help lady get something top shelf grocery store made happy thought nice something see everyday',
#  'daughter took naps day totaling hours allowed hours quiet time',
#  'went date cute guy crush awhile',
#  'able complete everything schedule yesterday made feel productive',
#  'boyfriend told smart beautiful left work felt loved appreciated',
#  'came home work two little grandsons playing front yard',
#  'went gym felt proud',
#  'managed make writing',
#  'yesterday donuts work celebrate coworkers birthday nice surprise',
#  'colleagues finished project ve working',
#  'went short day hike wilderness park',
#  'went walk husband dog sun shining birds singing perfect spring day',
#  'gym hit new record different lifts',
#  'finally convinced girlfriend go movies lot fun nice night',
#  'friend took lunch today',
#  'laughing joking mother morning made happy',
#  'went swimming florida vacation family',
#  'today son s birthday excited open gifts us',
#  'yesterday found bought persimmon tree home depot later planted tree front yard',
#  'played dog',
#  'made delicious cheeseburger afternoon came great',
#  'listened happy song',
#  'gave homeless person money',
#  'seeing sister today away months college',
#  'coworkers making steps help getting hours work would give benefits higher pay',
#  'playing video game friend',
#  'made new friend online',
#  'husband drove mall day weather perfect',
#  'went walk since nice day',
#  'ran lap around neighborhood broke previous record',
#  'managed make mechanical turk made happy m putting money towards new office chair m way',
#  'watched wonderful movie seen years family thrilled',
#  'played hours video games closest friends',
#  'son actually acknowledged woke morning instead grunting',
#  'finally receiving package waiting',
#  'long match online card game called hearthstone',
#  'spending time girlfriend last night',
#  'found fifty dollars floor broke needed buy lunch',
#  'gave fiancee hug',
#  'watched entirety pharrell s new hour music video happy aon mute hour chunks course several days still alive',
#  'basically got eye exam really helped eyes diabetes suffering vision problems ended getting prescription glasses eyes',
#  'weather nice planted first vegetables season grow weather nicely',
#  'went lunch father nt seen since christmas',
#  'felt happy today guy interested asked hang later tonight',
#  'daughter told loved hugged bed time',
#  'sent home early work',
#  'worked gym got lot done',
#  'coworker brought donuts breakfast',
#  'daughter blurting happy birthday happened wife s birthday passed away april',
#  'given promotion work',
#  'wife horny morning',
#  'got call job interview nt think qualified',
#  'happy listened album wildflowers vinyl',
#  'set new personal record squats one repetition pounds',
#  'happiness mental emotional state wellbeing defined positive pleasant emotions ranging contentment intense joy happy mental states may also reflect judgements person overall wellbeing variety biological psychological economic religious philosophical approaches striven define happiness identify sources various research groups including positive psychology happiness economics employing scientific method research questions happiness might attained',
#  'went dunkin donuts girl wrote sexy cup name noticed couple hours later made happy',
#  'walked steps equaled whole mile continue confidence breaker',
#  'able achieve something difficult work made coworker really happy',
#  'finished backlog paperwork work help',
#  'got chinese food dinner good',
#  'friend sheryl came visit puppy',
#  'started small business',
#  'sitting talking neighbor',
#  'talking girlfriend phone making weekend plans',
#  'made final table poker tournament',
#  'benched pressed pounds last week passed one rep max',
#  'small young calf really sick think would make got last night standing really well happy proud little guy',
#  'getting new vape pax mail today ve waiting joy',
#  'made happy got get fries lunch earlier',
#  'got period course sucks lets know everything s good healthwise',
#  'bought new top favorite store',
#  'went outside see warm enough bike ride went three mile ride never rode far one session happy good excercise',
#  'boss rewarded tickets pro hockey game s played later week',
#  'helped plan surprise party mom s th birthday party coming',
#  'went bathroom',
#  'ate delicious dinner husband',
#  'dollars lottery scratch',
#  'able get established better ground therapist',
#  'free session school means minutes learning',
#  'great workout gym',
#  'husband walked way nearby store picked beautiful card make feel better nt walk made even special',
#  'progressed barbell bench press plateauing',
#  'finished making mega cake friend s birthday came great',
#  'really happy finished midterm felt decently well happy',
#  'husband gave lingering hug kisses left work',
#  'got korean barbecue nearby food cart',
#  'made big dinner girlfriend last evening',
#  'came home okay new puppy happy see',
#  'baby woke silly happy felt happy refreshed fairly good night sleep enjoyed silliness',
#  'got full night sleep often happen monthold house',
#  'today dog s birthday fun playing present',
#  'found interesting book library book nt know existed',
#  'went gym exercised elliptical lifted weights work',
#  'finally completed long tiring task work',
#  'went local bar dinner old friend',
#  'increased max bench press morning heaviest ve ever lifted',
#  'took daughter lacrosse practice watched play',
#  'way home purchased purple flower plant gave significant arrived home work seeing reaction made heart glow',
#  'saw son trying make grilled cheese stove nt working well bread falling apart cheese burning came helped made one ate together made feel warm teach something even simple',
#  'happy got email discount triathlon wanted',
#  'cooked new recipe ve wanting try turned well',
#  'watched funny movie together husband enjoyed',
#  'dog listened asked stay door went mailbox',
#  'got stay home work today take care stuff around house',
#  'picked daughter school happy see',
#  'husband came home morning get changed ready work nice see bit',
#  'got lot hours work yesterday good need money',
#  'ate pretty healthy today felt good',
#  'made happy today learn made hard biology test',
#  'watched blackhawks game last night',
#  'boyfriend got phone call saying lost phone found',
#  'met friends tea bible study session really fun engaging',
#  'husband get long really well lovely day yesterday coffee watched news discussed thoughts simple things make happiest',
#  'nest birds horse s stall s beam ve watching mother bird build awhile went stall today saw could hear baby birds chirping made happy see hatched',
#  'got eat dinner girlfriend sat bar watch game',
#  'm trying study individual frames animation m pleased results',
#  'weighed morning lost weight lbs exact',
#  'today made happy able enjoy time coworkers outside work',
#  'happy take sunday afternoon nap',
#  'playing videogame friend',
#  'complete pending job task today',
#  'couple hours ago found got exam prepared long time',
#  'im pilot flew today',
#  'accepted new apartment',
#  'enjoyed fishing family early morning',
#  'realized aca people count support getting keeping health coverage',
#  'got really lucky drafted possibly best deck ve ever hearthstone video game destroying first opponents simultaneously going bag lindt chocolate truffles realized really really happy feeling euphoria lasted another minutes lost three straight games back normal',
#  'favorite tv show came',
#  'went sisters saw new baby smile',
#  'today received new laptop amazon even arrived day early',
#  'completed online course putting',
#  'happy online order arrived incredibly quickly',
#  'worked garden nice warm weather plants growing nicely air clean',
#  'cream chicken soup dinner made feel lot better sick',
#  'supervisor told m really good worker consider applying higher job workplace',
#  'got take walk month old son husband weather ver beautiful right cool sunny',
#  'talked phone best friend laughed lot',
#  'booked flight colombia',
#  'gave daughter present witnessed joy',
#  'received large unexpected bonus mturk requester earlier today great every little bit helps',
#  'ran mile minutes today made feel fast',
#  'went hike dog beautiful sunny day park almost',
#  'given stranger line coffee today',
#  'talked boyfriend',
#  'able help friend get money ssi',
#  'girl crush showed gym working morning',
#  'get money ssi',
#  'completed book reading really enjoyed',
#  'got babysit grandchildren love spend time',
#  'picking girlfriend airport since nt seen two weeks',
#  'got meet old friends celebrate one birthdays',
#  'received new instrument classroom expecting arrive',
#  'danced soca music mom sister',
#  'made happy receiving grades college getting s b',
#  'suffering stomach bug husband made multiple trips walgreens grab gatorade medicine made feel loved',
#  'got sitting plane several hours stretched',
#  'picture published college s newspaper',
#  'ex girlfriend texted talked phone well',
#  'th birthday',
#  'girlfriend told really happy happy met',
#  'spring break right work job much calm normal gotten spend quality time students relax',
#  'watched tv shows',
#  'watched particularly compelling episode show enjoy netflix',
#  'got new darts electronic dart board basement got finally play',
#  'trying lose weight lately diet exercise morning woke weighed ve lost whole pounds made happy felt rewarding',
#  'professor gave extension assignment',
#  'told school teach closed week teachers still paid',
#  'got government job friends meeting friends get gather party m going movie friends also movie',
#  'happy someone owed money paid back last night',
#  'went n work starving double double tasted good',
#  'happy read email requester giving bonus',
#  'kids twin boys woke today kisses hugs',
#  'went beach girlfriend nice seeing beautiful sunset go holding arms grateful life',
#  'ate chikfila',
#  'walked classroom students ran excitedly hugged',
#  'stray cat hanging back porch last night finally found s way home getting worried',
#  'purchased new pants two sizes smaller usually buy',
#  'daughter committed college']

# %%
# Convert it to dataframe
data_cleaned = pd.DataFrame(data_cleaned)

# Rename the column
data_cleaned = data_cleaned.rename(columns = {0 : 'cleaned_hm'})

# Add Target variable to the dataframe
#data_cleaned['predicted_category'] = rawData['predicted_category']

data_cleaned
# Out:
#                                             cleaned_hm
# 0    went successful date someone felt sympathy con...
# 1                      happy son got marks examination
# 2                                went gym morning yoga
# 3    serious talk friends flaky lately understood g...
# 4    went grandchildren butterfly display crohn con...
# ..                                                 ...
# 995                                       ate chikfila
# 996     walked classroom students ran excitedly hugged
# 997  stray cat hanging back porch last night finall...
# 998  purchased new pants two sizes smaller usually buy
# 999                         daughter committed college
#
# [1000 rows x 1 columns]

# %% [markdown]
# ### Stemming

# %%
# Perform Stemming
def stemming(line):
    stem_sentence = []
    words = word_tokenize(line)
    ps = PorterStemmer()
    for w in words:
        root_word = ps.stem(w)
        stem_sentence.append(root_word)
    final_sentence = " ".join(stem_sentence)
    #print(final_sentence)
    return final_sentence

# %%
# Function call for stemming
stemmedData = [stemming(data_cleaned['cleaned_hm'][i]) for i in range(0, data_cleaned.shape[0])]

# %%
# Converting it to dataframe
stemmedData = pd.DataFrame(stemmedData)

# Renaming the column
stemmedData = stemmedData.rename(columns = {0 : 'cleaned_hm'})

stemmedData
# Out:
#                                             cleaned_hm
# 0       went success date someon felt sympathi connect
# 1                            happi son got mark examin
# 2                                   went gym morn yoga
# 3    seriou talk friend flaki late understood good ...
# 4    went grandchildren butterfli display crohn con...
# ..                                                 ...
# 995                                       ate chikfila
# 996           walk classroom student ran excitedli hug
# 997  stray cat hang back porch last night final fou...
# 998        purchas new pant two size smaller usual buy
# 999                             daughter commit colleg
#
# [1000 rows x 1 columns]

# %% [markdown]
# ### Lemmatization

# %%
def lemmatize(line):
    lemmetized_sentence = []
    lemmatizer = WordNetLemmatizer()
    for w in line:
        l = lemmatizer.lemmatize(w)
        lemmetized_sentence.append(l)
    final_sentence = "".join(lemmetized_sentence)
    #print(final_sentence)
    return final_sentence

# %%
# Function call for lemmatizing
lemmatized_data = [lemmatize(stemmedData['cleaned_hm'][i]) for i in range(0, stemmedData.shape[0])]

# %%
# Convert it to dataframe
dataAsDF = pd.DataFrame(lemmatized_data)

# Rename the column
dataAsDF = dataAsDF.rename(columns = {0 : 'cleaned_hm'})

dataAsDF
# Out:
#                                             cleaned_hm
# 0       went success date someon felt sympathi connect
# 1                            happi son got mark examin
# 2                                   went gym morn yoga
# 3    seriou talk friend flaki late understood good ...
# 4    went grandchildren butterfli display crohn con...
# ..                                                 ...
# 995                                       ate chikfila
# 996           walk classroom student ran excitedli hug
# 997  stray cat hang back porch last night final fou...
# 998        purchas new pant two size smaller usual buy
# 999                             daughter commit colleg
#
# [1000 rows x 1 columns]

# %% [markdown]
# ### Vectorizing Text Data

# %%
# COUNT VECTORIZER

# stops_ = set(STOPWORDS)
# stops.update(stops_)

count_vec = CountVectorizer(ngram_range = (1,3)) #stop_words=stops)
inputDF = pd.DataFrame(count_vec.fit_transform(dataAsDF['cleaned_hm']).toarray())

print(inputDF.shape)
# print(count_vec.get_feature_names())
# Out:
# (1000, 16377)

# %%
# TF-IDF VECTORIZER

# count_vec = TfidfVectorizer()
# inputDF = pd.DataFrame(count_vec.fit_transform(dataAsDF['cleaned_hm']).toarray())

# It is giving less ACCURACY

# %%
outputDF = pd.DataFrame(rawData['predicted_category'])
outputDF = outputDF.rename(columns = {'predicted_category' : 'category'})
print(outputDF.shape)
outputDF
# Out:
# (1000, 1)
#              category
# 0           affection
# 1           affection
# 2            exercise
# 3             bonding
# 4           affection
# ..                ...
# 995  enjoy_the_moment
# 996           bonding
# 997  enjoy_the_moment
# 998       achievement
# 999         affection
#
# [1000 rows x 1 columns]

# %%
# Convert target columns to categories
#outputDF = pd.DataFrame(outputDF.predicted_category.astype('category').cat.codes)
outputDF['category'] = outputDF['category'].map({'achievement':0, 'affection':1, 'bonding':2, 'enjoy_the_moment':3, 'exercise':4, 'leisure':5, 'nature':6})
outputDF
# Out:
#      category
# 0           1
# 1           1
# 2           4
# 3           2
# 4           1
# ..        ...
# 995         3
# 996         2
# 997         3
# 998         0
# 999         1
#
# [1000 rows x 1 columns]

# %% [markdown]
# ### Splitting Data for Training and Testing

# %%
# Splitting Train and Test data
xtrain, xtest, ytrain, ytest = train_test_split(inputDF, outputDF, test_size = 0.2, random_state = 201)

# %%
print(xtrain.shape, ytrain.shape, xtest.shape, ytest.shape)
# Out:
# (800, 16377) (800, 1) (200, 16377) (200, 1)

# %% [markdown]
# ### Creating Classification Models

# %% [markdown]
# #### Multinomial Naive Bayes Classifier

# %%
MNB_clf = MultinomialNB()
MNB_clf.fit(xtrain,ytrain)

predicted_train = MNB_clf.predict(xtrain)
train_accuracy = accuracy_score(ytrain, predicted_train, normalize = True, sample_weight=None)
print('Train accuracy: ', train_accuracy)

predicted_test = MNB_clf.predict(xtest)
test_accuracy = accuracy_score(ytest, predicted_test, normalize = True, sample_weight=None)
print('Test accuracy: ', test_accuracy)

#MNB_clf.score(xtest,ytest)
# Out:
# C:\Users\SANDEEP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Train accuracy:  0.985
# Test accuracy:  0.725

# %% [markdown]
# #### Decision Tree Classifier

# %%
DT_clf = DecisionTreeClassifier()
DT_clf.fit(xtrain,ytrain)
DT_clf.score(xtest,ytest)
# Out:
# 0.68

# %% [markdown]
# #### Support Vector Machines

# %%
SVM_clf = svm.SVC()
SVM_clf.fit(xtrain, ytrain)
SVM_clf.score(xtest, ytest)
# Out:
# C:\Users\SANDEEP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\SANDEEP\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.34

# %% [markdown]
# #### Random Forest Classifier

# %%
RF_clf = RandomForestClassifier()
RF_clf.fit(xtrain, ytrain)
RF_clf.score(xtest, ytest)
# Out:
# C:\Users\SANDEEP\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\SANDEEP\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 0.645

# %% [markdown]
# MultinomialNB classifier is yielding more Accuracy.

# %% [markdown]
# # Testing

# %%
test_data = pd.read_csv("dataset/hm_test.csv")
test_data
# Out:
#          hmid reflection_period  \
# 0       88305                3m
# 1       88306                3m
# 2       88307                3m
# 3       88308                3m
# 4       88309                3m
# ...       ...               ...
# 40208  128762               24h
# 40209  128763               24h
# 40210  128764               24h
# 40211  128765               24h
# 40212  128766               24h
#
#                                               cleaned_hm  num_sentence
# 0        I spent the weekend in Chicago with my friends.             1
# 1      We moved back into our house after a remodel. ...             2
# 2      My fiance proposed to me in front of my family...             1
# 3      I ate lobster at a fancy restaurant with some ...             1
# 4      I went out to a nice restaurant on a date with...             5
# ...                                                  ...           ...
# 40208  My husband announced he is getting a decent bo...             1
# 40209                       Had a can of Pepsi to drink.             1
# 40210            Cuddling with my girlfriend last night.             1
# 40211  I had a great meeting yesterday at work with m...             1
# 40212                  I had a great workout last night.             1
#
# [40213 rows x 4 columns]

# %%
test_data.shape
# Out:
# (40213, 4)

# %%
test_data = test_data.iloc[:1000, ]
test_data.shape
# Out:
# (1000, 4)

# %% [markdown]
# ### Removing stop words, punctuations, numbers, hypens, white spaces from text

# %%
test_data_cleaned = [clean(test_data.iloc[i,2]) for i in range(0, test_data.shape[0])]
test_data_cleaned = pd.DataFrame(test_data_cleaned)
test_data_cleaned = test_data_cleaned.rename(columns = {0 : 'cleaned_hm'})
test_data_cleaned
# Out:
#                                             cleaned_hm
# 0                        spent weekend chicago friends
# 1    moved back house remodel lived hotel months du...
# 2         fiance proposed front family beginning march
# 3                 ate lobster fancy restaurant friends
# 4    went nice restaurant date wife popular restaur...
# ..                                                 ...
# 995                  went outside watered flowers yard
# 996                  went favorite bakery got macarons
# 997  got promoted work go dream level worked years ...
# 998                 heard back aunt received promotion
# 999                        saw cutest looking dog park
#
# [1000 rows x 1 columns]

# %% [markdown]
# ### Stemming

# %%
test_data_stemmed = [stemming(test_data_cleaned['cleaned_hm'][i]) for i in range(0, test_data_cleaned.shape[0])]

# %%
test_data_stemmed = pd.DataFrame(test_data_stemmed)
test_data_stemmed = test_data_stemmed.rename(columns = {0 : 'cleaned_hm'})
test_data_stemmed
# Out:
#                                             cleaned_hm
# 0                         spent weekend chicago friend
# 1    move back hous remodel live hotel month due ho...
# 2                fianc propos front famili begin march
# 3                     ate lobster fanci restaur friend
# 4    went nice restaur date wife popular restaur co...
# ..                                                 ...
# 995                      went outsid water flower yard
# 996                    went favorit bakeri got macaron
# 997  got promot work go dream level work year reach...
# 998                      heard back aunt receiv promot
# 999                           saw cutest look dog park
#
# [1000 rows x 1 columns]

# %% [markdown]
# ### Lemmetization

# %%
test_data_lemmetized = [lemmatize(test_data_stemmed['cleaned_hm'][i]) for i in range(0, test_data_stemmed.shape[0])]

# %%
test_data_lemmetized = pd.DataFrame(test_data_lemmetized)
test_data_lemmetized = test_data_lemmetized.rename(columns = {0 : 'cleaned_hm'})
test_data_lemmetized
# Out:
#                                             cleaned_hm
# 0                         spent weekend chicago friend
# 1    move back hous remodel live hotel month due ho...
# 2                fianc propos front famili begin march
# 3                     ate lobster fanci restaur friend
# 4    went nice restaur date wife popular restaur co...
# ..                                                 ...
# 995                      went outsid water flower yard
# 996                    went favorit bakeri got macaron
# 997  got promot work go dream level work year reach...
# 998                      heard back aunt receiv promot
# 999                           saw cutest look dog park
#
# [1000 rows x 1 columns]

# %% [markdown]
# ### Vectorizing Text data

# %%
test_inputDF = pd.DataFrame(count_vec.transform(test_data_lemmetized['cleaned_hm']).toarray())
test_inputDF.shape
# Out:
# (1000, 16377)

# %%
predicted_output = MNB_clf.predict(test_inputDF)
predicted_output = pd.DataFrame(predicted_output)
predicted_output = predicted_output.rename(columns = {0 : 'predicted_output'})
predicted_output['predicted_output'] = predicted_output['predicted_output'].map({0:'achievement', 1:'affection', 2:'bonding', 3:'enjoy_the_moment', 4:'exercise', 5:'leisure', 6:'nature'})
predicted_output
# Out:
#     predicted_output
# 0          affection
# 1          affection
# 2          affection
# 3            bonding
# 4          affection
# ..               ...
# 995        affection
# 996        affection
# 997      achievement
# 998      achievement
# 999        affection
#
# [1000 rows x 1 columns]

# %%
final_predicted = pd.DataFrame(test_data[['hmid','cleaned_hm']])
final_predicted['predicted_output'] = predicted_output
final_predicted
# Out:
#       hmid                                         cleaned_hm predicted_output
# 0    88305    I spent the weekend in Chicago with my friends.        affection
# 1    88306  We moved back into our house after a remodel. ...        affection
# 2    88307  My fiance proposed to me in front of my family...        affection
# 3    88308  I ate lobster at a fancy restaurant with some ...          bonding
# 4    88309  I went out to a nice restaurant on a date with...        affection
# ..     ...                                                ...              ...
# 995  89304  I went outside and watered some flowers in my ...        affection
# 996  89305    We went to my favorite bakery and got macarons.        affection
# 997  89306  I got promoted at work. I go the y dream level...      achievement
# 998  89307  I heard back from my aunt that she received a ...      achievement
# 999  89308          I saw the cutest looking dog at the park.        affection
#
# [1000 rows x 3 columns]

# %%
# Counts of Unique values
final_predicted['predicted_output'].value_counts()
# Out:
# affection           521
# achievement         404
# bonding              59
# enjoy_the_moment      8
# leisure               5
# exercise              3
# Name: predicted_output, dtype: int64

# %%
# Writting to csv file
final_predicted.to_csv('final_predicted.csv', index=False)

# %% [markdown]
# # DONE
